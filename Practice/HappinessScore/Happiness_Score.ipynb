# %%
import pandas as pd
df = pd.read_csv('happiness_score_dataset.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.shape
# Out:
# (158, 12)

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# we have 2 object type features and 10 numeric features.

# %%
Regions = df['Region'].unique()

# %%
Regions
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# We don't have any null values.

# %%
HS_features= ["Economy (GDP per Capita)","Family","Health (Life Expectancy)","Freedom","Trust (Government Corruption)","Generosity","Dystopia Residual"]

# %%
R_features = ["Happiness Score","Economy (GDP per Capita)","Family","Health (Life Expectancy)","Freedom","Trust (Government Corruption)","Generosity","Dystopia Residual"]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.xlabel("Economy (GDP per Capita)")
plt.ylabel('Happiness score')
plt.title("Plot between Happiness score and Economy (GDP per Capita)")
sns.scatterplot(x=df["Economy (GDP per Capita)"],y=df["Happiness Score"],hue=df['Region'],s=200)
# Out:
# <AxesSubplot:title={'center':'Plot between Happiness score and Economy (GDP per Capita)'}, xlabel='Economy (GDP per Capita)', ylabel='Happiness score'>

# %% [markdown]
# Happiness score is directly proportonal to Economy (GDP per Capita)

# %%
plt.xlabel("Family")
#plt.ylabel('Happiness score')
plt.title("Plot between happiness score and Family")
sns.scatterplot(x=df["Family"],y=df["Happiness Score"],hue=df["Region"],s=200)
# Out:
# <AxesSubplot:title={'center':'Plot between happiness score and Family'}, xlabel='Family', ylabel='Happiness Score'>

# %% [markdown]
# Happiness score is directly proportional to Family

# %%
plt.xlabel("Health (Life Expectancy)")
plt.title("Plot between Happiness Score and Health (Life Expectancy)")
sns.scatterplot(x=df["Health (Life Expectancy)"],y=df["Happiness Score"], hue=df["Region"],s=200)
# Out:
# <AxesSubplot:title={'center':'Plot between Happiness Score and Health (Life Expectancy)'}, xlabel='Health (Life Expectancy)', ylabel='Happiness Score'>

# %% [markdown]
# Happiness score is directly proportional to Health

# %%
plt.xlabel("Freedom")
plt.title("Plot between Happiness score and Freedom")
sns.scatterplot(x=df["Freedom"],y=df["Happiness Score"],hue=df["Region"],s=200)
# Out:
# <AxesSubplot:title={'center':'Plot between Happiness score and Freedom'}, xlabel='Freedom', ylabel='Happiness Score'>

# %% [markdown]
# - Happiness score is quite proportional to Freedom

# %%
plt.xlabel("Trust (Government Corruption)")
plt.title("Plot between Happiness Score and Trust (Government Corruption) ")
sns.scatterplot(x=df["Trust (Government Corruption)"],y=df["Happiness Score"],hue=df["Region"],s=200)
# Out:
# <AxesSubplot:title={'center':'Plot between Happiness Score and Trust (Government Corruption) '}, xlabel='Trust (Government Corruption)', ylabel='Happiness Score'>

# %% [markdown]
# - Corruption has little to do with Happiness score.

# %%
plt.xlabel("")
plt.title("Plot between Happiness Score and Generosity")
sns.scatterplot(x=df["Generosity"],y=df["Happiness Score"],hue=df["Region"],s=200)
# Out:
# <AxesSubplot:title={'center':'Plot between Happiness Score and Generosity'}, xlabel='Generosity', ylabel='Happiness Score'>

# %% [markdown]
# - Happiness score is directly proportional to Generosity
# - Generosity is dense in  the range 1-3.5

# %%
plt.xlabel("Dystopia Residual")
plt.title("Plot between Happiness score and Dystopia Residual")
sns.scatterplot(x=df["Dystopia Residual"],y=df["Happiness Score"],hue=df["Region"],s=200)
# Out:
# <AxesSubplot:title={'center':'Plot between Happiness score and Dystopia Residual'}, xlabel='Dystopia Residual', ylabel='Happiness Score'>

# %% [markdown]
# - Happiness score is proportional to Dystopia residual

# %%
plt.xlabel("Economy (GDP per Capita)")
plt.title(" Plot between happiness score and Economy (GDP per Capita)")
sns.scatterplot(x= df["Economy (GDP per Capita)"],y= df["Happiness Score"], hue=df["Region"], s=200)
# Out:
# <AxesSubplot:title={'center':' Plot between happiness score and Economy (GDP per Capita)'}, xlabel='Economy (GDP per Capita)', ylabel='Happiness Score'>

# %% [markdown]
# - Happiness score is proportional to Economy (GDP per Capita)

# %%
plt.xlabel("Family")
plt.title("Plot between Family and Happiness score")
sns.scatterplot(x=df["Family"],y=df["Happiness Score"], hue=df["Region"], s=200)
# Out:
# <AxesSubplot:title={'center':'Plot between Family and Happiness score'}, xlabel='Family', ylabel='Happiness Score'>

# %% [markdown]
# -Happiness score is directly proportional to Family

# %%
plt.xlabel("Standard Error")
plt.title("Plot between Happiness score and Standard Error")
sns.scatterplot(x=df["Standard Error"],y= df["Happiness Score"], hue=df["Region"], s=200)
# Out:
# <AxesSubplot:title={'center':'Plot between Happiness score and Standard Error'}, xlabel='Standard Error', ylabel='Happiness Score'>

# %% [markdown]
# - There is no direct relation between Standard error and Happiness score
# - Standard error is dense in range 3-5.

# %%
plt.xlabel("Happiness rank")
plt.title("Plot between Happiness score and happiness rank")
sns.scatterplot(x=df["Happiness Rank"], y=df["Happiness Score"], hue =df["Region"],s=200)
# Out:
# <AxesSubplot:title={'center':'Plot between Happiness score and happiness rank'}, xlabel='Happiness rank', ylabel='Happiness Score'>

# %% [markdown]
# - Happiness score is proportional to Happiness Rank

# %% [markdown]
# # Dropping extra columns

# %%
df.drop(["Country", "Region", "Happiness Rank"],axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Happiness Score', 'Standard Error', 'Economy (GDP per Capita)',
#        'Family', 'Health (Life Expectancy)', 'Freedom',
#        'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.corr()
# Out:
#                                Happiness Score  Standard Error  \
# Happiness Score                       1.000000       -0.177254
# Standard Error                       -0.177254        1.000000
# Economy (GDP per Capita)              0.780966       -0.217651
# Family                                0.740605       -0.120728
# Health (Life Expectancy)              0.724200       -0.310287
# Freedom                               0.568211       -0.129773
# Trust (Government Corruption)         0.395199       -0.178325
# Generosity                            0.180319       -0.088439
# Dystopia Residual                     0.530474        0.083981
#
#                                Economy (GDP per Capita)    Family  \
# Happiness Score                                0.780966  0.740605
# Standard Error                                -0.217651 -0.120728
# Economy (GDP per Capita)                       1.000000  0.645299
# Family                                         0.645299  1.000000
# ...

# %%
plt.figure(figsize =(15,7))
sns.heatmap(df.corr(),annot=True, fmt= '0.2f',linewidth = 4, linecolor = 'black')
plt.show()

# %% [markdown]
# - Happiness score is highly ( positively ) correlated to Economy(GDP per Capita), Family, Health(Life Expectancy)
# - Happiness score is moderately (positively) correlated with Freedom, Trust(Government Corruption), Dystopia Residual
# - Happiness score have very low correlation with Standard Error (-0.18) and Generosity (+0.18)

# %%
df.describe()
# Out:
#        Happiness Score  Standard Error  Economy (GDP per Capita)      Family  \
# count       158.000000      158.000000                158.000000  158.000000
# mean          5.375734        0.047885                  0.846137    0.991046
# std           1.145010        0.017146                  0.403121    0.272369
# min           2.839000        0.018480                  0.000000    0.000000
# 25%           4.526000        0.037268                  0.545808    0.856823
# 50%           5.232500        0.043940                  0.910245    1.029510
# 75%           6.243750        0.052300                  1.158448    1.214405
# max           7.587000        0.136930                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                158.000000  158.000000                     158.000000
# mean                   0.630259    0.428615                       0.143422
# ...

# %% [markdown]
# - Here we find we have almost no difference in mean and median (i.e. 50% value) of the inputs, hence we say there is very little skewness present.

# %%
df.skew()
# Out:
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# - Skewness range lies b/w +-0.5
# - Considering skewness range Standard Error, Family, Health (Life Expectancy), Trust (Government Corruption), Generosity are the inputs with little skewness present in data.

# %%
for i in df.columns:
    plt.figure(figsize=(5,5))
    sns.distplot(df[i])
    plt.show()
# Out:
# <ipython-input-31-205ab10ee0ed>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-31-205ab10ee0ed>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-31-205ab10ee0ed>:3: UserWarning:
#
# ...

# %% [markdown]
# - Happiness score data is normally distributed
# - Standard Error data is right skewed
# - Economy(GDP per Capita) data is left skewed
# - Family data is left skewed
# - Health(Life Expectancy) data is left skewed
# - Freedom data is almost normally distributed
# - Trust(Government Corruption)is right skewed
# - Generosity is right skewed
# - Dystopia Residual is almost normally distributed

# %%
#Dropping Standard error and Geneorisity as they have low correlation and high skewness.
df.drop(["Standard Error", "Generosity"], inplace = True, axis=1)

# %%
df
# Out:
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.587                   1.39651  1.34951
# 1              7.561                   1.30232  1.40223
# 2              7.527                   1.32548  1.36058
# 3              7.522                   1.45900  1.33095
# 4              7.427                   1.32629  1.32261
# ..               ...                       ...      ...
# 153            3.465                   0.22208  0.77370
# 154            3.340                   0.28665  0.35386
# 155            3.006                   0.66320  0.47489
# 156            2.905                   0.01530  0.41587
# 157            2.839                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# ...

# %%
df.dtypes
# Out:
# Happiness Score                  float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# - All Inputs are flot hence we don't need any encoding or labelling.

# %% [markdown]
# # Checking Outlier

# %%
cols =df.columns

# %%
cols
# Out:
# Index(['Happiness Score', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Dystopia Residual'],
#       dtype='object')

# %%
ncols=30
nrows=14
plt.figure(figsize=(ncols,3*ncols))

for i in range(0,len(cols)):
    plt.subplot(nrows,ncols,i+1)
    sns.boxplot(df[cols[i]],orient='v')
    plt.tight_layout()

# %% [markdown]
# Outliers are present in
# - Family
# - Trust
# - Dystopia

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z
# Out:
# array([[1.93736005, 1.36962124, 1.32028142, ..., 1.57743784, 2.30965159,
#         0.75825809],
#        [1.91458063, 1.13522625, 1.51445776, ..., 1.33245589, 0.01647953,
#         1.09285682],
#        [1.88479215, 1.19286069, 1.36105403, ..., 1.4696591 , 2.8427738 ,
#         0.71233526],
#        ...,
#        [2.0761992 , 0.45524543, 1.90108634, ..., 1.80923785, 0.38141902,
#         3.20843049],
#        [2.1646885 , 2.06756644, 2.1184666 , ..., 2.06447176, 0.35771452,
#         0.48198451],
#        [2.22251319, 1.58633379, 3.13472485, ..., 0.42662099, 0.30180313,
#         0.96361241]])

# %%
outlier = np.where(z>3)
outlier
# Out:
# (array([ 27, 147, 153, 155, 157]), array([5, 2, 5, 6, 2]))

# %%
df_new = df[(z<3).all(axis=1)]
df_new
# Out:
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.587                   1.39651  1.34951
# 1              7.561                   1.30232  1.40223
# 2              7.527                   1.32548  1.36058
# 3              7.522                   1.45900  1.33095
# 4              7.427                   1.32629  1.32261
# ..               ...                       ...      ...
# 150            3.655                   0.46534  0.77115
# 151            3.587                   0.25812  0.85188
# 152            3.575                   0.31982  0.30285
# 154            3.340                   0.28665  0.35386
# 156            2.905                   0.01530  0.41587
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# ...

# %%
df.shape
# Out:
# (158, 7)

# %%
df_new.shape
# Out:
# (153, 7)

# %%
#percentage loss due to removal of outlier
loss = 500/158
loss
# Out:
# 3.1645569620253164

# %% [markdown]
# 3.1 % loss is acceptable.

# %%
df_new
# Out:
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.587                   1.39651  1.34951
# 1              7.561                   1.30232  1.40223
# 2              7.527                   1.32548  1.36058
# 3              7.522                   1.45900  1.33095
# 4              7.427                   1.32629  1.32261
# ..               ...                       ...      ...
# 150            3.655                   0.46534  0.77115
# 151            3.587                   0.25812  0.85188
# 152            3.575                   0.31982  0.30285
# 154            3.340                   0.28665  0.35386
# 156            2.905                   0.01530  0.41587
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# ...

# %%
#Dividing into target variable and input variable
y= df_new['Happiness Score']
x= df_new.drop(['Happiness Score'],axis =1)
y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 150    3.655
# 151    3.587
# 152    3.575
# 154    3.340
# 156    2.905
# Name: Happiness Score, Length: 153, dtype: float64

# %%
x
# Out:
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# 3                     1.45900  1.33095                   0.88521  0.66973
# 4                     1.32629  1.32261                   0.90563  0.63297
# ..                        ...      ...                       ...      ...
# 150                   0.46534  0.77115                   0.15185  0.46866
# 151                   0.25812  0.85188                   0.27125  0.39493
# 152                   0.31982  0.30285                   0.30335  0.23414
# 154                   0.28665  0.35386                   0.31910  0.48450
# 156                   0.01530  0.41587                   0.22396  0.11850
#
#      Trust (Government Corruption)  Dystopia Residual
# ...

# %%
from sklearn.preprocessing import power_transform
x= power_transform(x,method = "yeo-johnson")
x
# Out:
# array([[ 1.49533495e+00,  1.66651778e+00,  1.48458516e+00,
#          1.76895699e+00,  1.82520967e+00,  7.51971405e-01],
#        [ 1.20058451e+00,  2.01576571e+00,  1.52582536e+00,
#          1.45212783e+00,  3.47782848e-01,  1.10951985e+00],
#        [ 1.27226398e+00,  1.73823779e+00,  1.07189739e+00,
#          1.62818656e+00,  1.95995472e+00,  7.03015689e-01],
#        [ 1.69559649e+00,  1.54816774e+00,  1.13516484e+00,
#          1.80548030e+00,  1.67308466e+00,  6.51405768e-01],
#        [ 1.27478031e+00,  1.49575387e+00,  1.25955064e+00,
#          1.48772136e+00,  1.55087466e+00,  6.25255922e-01],
#        [ 1.16343474e+00,  1.46860318e+00,  1.15870059e+00,
#          1.56208497e+00,  1.81023853e+00,  9.49647403e-01],
#        [ 1.28457212e+00,  1.23629258e+00,  1.18130761e+00,
#          1.34279323e+00,  1.50670361e+00,  6.52158543e-01],
#        [ 1.29163440e+00,  1.28970745e+00,  1.29193182e+00,
#          1.71853734e+00,  1.86875590e+00,  4.69938539e-01],
# ...

# %%
#Scaling input data into the range of 0 and 1
from sklearn.preprocessing import MinMaxScaler
sc= MinMaxScaler()
x= sc.fit_transform(x)
x = pd.DataFrame(x)
x.columns = ['Economy (GDP per Capita)', 'Family',
       'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
       'Dystopia Residual']
x
# Out:
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                    0.863050  0.915005                  0.860684  0.991245
# 1                    0.788961  1.000000                  0.870897  0.915303
# 2                    0.806978  0.932459                  0.758478  0.957503
# 3                    0.913388  0.886202                  0.774147  1.000000
# 4                    0.807611  0.873447                  0.804952  0.923834
# ..                        ...       ...                       ...       ...
# 148                  0.228983  0.255701                  0.068573  0.615529
# 149                  0.119268  0.321438                  0.137964  0.493676
# 150                  0.150665  0.000000                  0.159177  0.261493
# 151                  0.133650  0.019009                  0.170002  0.643015
# 152                  0.006512  0.044676                  0.108731  0.121502
#
#      Trust (Government Corruption)  Dystopia Residual
# ...

# %% [markdown]
# here we can see data is now in the range of 0 and 1

# %%
#Dividing data into x_train, x_test, y_train, y_test
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score

best_rstate=0
accu=0

for i in range(30,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=i)
    mod=LinearRegression()
    mod.fit(x_train,y_train)
    y_pred=mod.predict(x_test)
    tempaccu=r2_score(y_test,y_pred)
    
    
    if tempaccu>accu:
        accu=tempaccu
        best_rstate=i
        
        
print('Best accuracy is ',(accu*100),'found on random state',(best_rstate))
# Out:
# Best accuracy is  99.37180941986256 found on random state 148

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=148)

# %%
print(x_test.shape,y_test.shape)
# Out:
# (39, 6) (39,)

# %%
import sklearn 
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
import warnings 
warnings.filterwarnings('ignore')


model=[LinearRegression(),DecisionTreeRegressor(),GradientBoostingRegressor()]

for m in model:
    m.fit(x_train,y_train)
    predm=m.predict(x_test)
    m.score(x_train,y_train)
    print('accuracy score of',m,'is:')
    print(r2_score(y_test,predm))
    print("cvscore=",cross_val_score(m,x,y,cv=5).mean())
    print('\n')
# Out:
# accuracy score of LinearRegression() is:
# 0.9937180941986256
# cvscore= 0.6634034221586734
#
#
# accuracy score of DecisionTreeRegressor() is:
# 0.812840887755273
# cvscore= -8.533956243194584
#
#
# accuracy score of GradientBoostingRegressor() is:
# 0.9164139992192353
# cvscore= -2.344753129212253
