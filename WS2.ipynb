# %% [markdown]
# # Solution to Q1

# %%
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException
from selenium.webdriver.common.by import By
import time
driver = webdriver.Chrome(r"/Users/pallavishu/Downloads/chromedriver")
driver.get("https://www.naukri.com/")
designation = driver.find_element(By.CLASS_NAME,"suggestor-input ")
designation.send_keys("Data Analyst")
location = driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div[3]/div/div/div[5]/div/div/div/input")
location.send_keys("Bangalore")
search = driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()
job_title = []
job_location = []
company_name = []
exp_required = []
title_tags = driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    title = i.text
    job_title.append(title)
title_location = driver.find_elements(By.XPATH,'//li[@class = "fleft grey-text br2 placeHolderLi location"]')
for i in title_location[0:10]:
    location = i.text
    job_location.append(location)
title_company = driver.find_elements(By.XPATH,'//a[@class = "subTitle ellipsis fleft"]')
for i in title_company[0:10]:
    company = i.text
    company_name.append(company)
title_exp = driver.find_elements(By.XPATH,'//span[@class = "class="ellipsis fleft fs12 lh16 expwdth"]')
for i in title_exp[0:10]:
    exp = i.text
    exp_required.append(exp)
df = pd.DataFrame({'job_title':job_title,'job_location':job_location, 'company_name': company_name,'Experience required':exp_required})
df

# %% [markdown]
# # Solution to Q2

# %%
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException
from selenium.webdriver.common.by import By
import time
driver = webdriver.Chrome(r"/Users/pallavishu/Downloads/chromedriver")
driver.get("https://www.naukri.com/")
designation = driver.find_element(By.CLASS_NAME,"suggestor-input ")
designation.send_keys("Data Scientist")
location = driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div[3]/div/div/div[5]/div/div/div/input")
location.send_keys("Bangalore")
search = driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()
job_title = []
job_location = []
company_name = []
title_tags = driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    title = i.text
    job_title.append(title)
title_location = driver.find_elements(By.XPATH,'//li[@class = "fleft grey-text br2 placeHolderLi location"]')
for i in title_location[0:10]:
    location = i.text
    job_location.append(location)
title_company = driver.find_elements(By.XPATH,'//a[@class = "subTitle ellipsis fleft"]')
for i in title_company[0:10]:
    company = i.text
    company_name.append(company)
df = pd.DataFrame({'Job tile':job_title,'Job location':job_location, 'Company name': company_name})
df

# %% [markdown]
# # Solution to Q3

# %%
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException
from selenium.webdriver.common.by import By
import time
driver = webdriver.Chrome(r"/Users/pallavishu/Downloads/chromedriver")
driver.get("https://www.naukri.com/")
designation = driver.find_element(By.CLASS_NAME,"suggestor-input ")
designation.send_keys("Data Scientist")
search = driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()
location_filter = driver.find_element(By.XPATH,'//span[@title="Delhi / NCR"]')
location_filter.click() 
salary_filter = driver.find_element(By.XPATH,'//span[@title="3-6 Lakhs"]')
salary.click();
job_title = []
job_location = []
company_name = []
exp_required = []
title_tags = driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    title = i.text
    job_title.append(title)
title_location = driver.find_elements(By.XPATH,'//li[@class = "fleft grey-text br2 placeHolderLi location"]')
for i in title_location[0:10]:
    location = i.text
    job_location.append(location)
title_company = driver.find_elements(By.XPATH,'//a[@class = "subTitle ellipsis fleft"]')
for i in title_company[0:10]:
    company = i.text
    company_name.append(company)
title_exp = driver.find_elements(By.XPATH,'//span[@class = "class="ellipsis fleft fs12 lh16 expwdth"]')
for i in title_exp[0:10]:
    exp = i.text
    exp_required.append(exp)
df = pd.DataFrame({'job_title':job_title,'job_location':job_location, 'company_name': company_name,'Experience required':exp_required})
df

# %% [markdown]
# # Solution to Q4

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException
from selenium.webdriver.common.by import By
import time
driver = webdriver.Chrome(r"/Users/pallavishu/Downloads/chromedriver")
driver.get("https://www.flipkart.com/")
product = driver.find_element(By.CLASS_NAME,"_3704LK")
product.send_keys("Sun glasses")
search = driver.find_element(By.CLASS_NAME,"_34RNph")
search.click()
url_class = driver.find_element(By.CLASS_NAME,"IRpwTa")
url = []
for i in url:
    link = i.get_attribute('href')
    url.append(link)
brands = []
product_dess = []
prices = []
start = 0
end =3
count =0
for page in range(start,end):
    brand=driver.find_elements(By.CLASS_NAME,"_2WkVRV")
    Desc=driver.find_elements(By.CLASS_NAME,"IRpwTa")
    Price=driver.find_elements(By.CLASS_NAME,"_30jeq3")
    if count <=100:
        for i in brand:
            BName = i.text
            brands.append(BName)
        for i in Desc:
            des = i.text
            product_dess.append(des)
        for i in Price:
            price = i.text
            prices.append(price)
        count = count + 1
        try:
            driver.get(url[1].get_attribute('href'))
        except:
            driver.get(url[0].get_attribute('href'))  
df = pd.DataFrame({'brand':brands,'product description':product_dess, 'price': prices})
df

# %% [markdown]
# # Solution to Q5

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException
from selenium.webdriver.common.by import By
import time
driver = webdriver.Chrome(r"/Users/pallavishu/Downloads/chromedriver")
driver.get("https://www.flipkart.com/")
product = driver.find_element(By.CLASS_NAME,"_3704LK")
product.send_keys("Iphone 11")
search = driver.find_element(By.CLASS_NAME,"_34RNph")
search.click()
iphoneTag = driver.find_element(By.CLASS_NAME,"_1fQZEK")
link = iphoneTag.get_attribute('href')
driver.get(link)
ratings = []
summaries = []
count  = 0
Ratings = driver.find_elements(By.XPATH,'//div[@class ="_3LWZlK _1BLPMq"]')
Summaries = driver.find_elements(By.XPATH,'//p[@class ="_2-N8zT"]')
if count <=100:
    for i in Ratings:
        rating = i.text
        ratings.append(rating)
    for i in Summaries:
        summary = i.text
        summaries.append(summary)
    count = count + 1
df = pd.DataFrame({'rating':ratings,'summary':summaries})
df

# %% [markdown]
# # Solution to Q6

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException
from selenium.webdriver.common.by import By
import time
driver = webdriver.Chrome(r"/Users/pallavishu/Downloads/chromedriver")
driver.get("https://www.flipkart.com/")
product = driver.find_element(By.CLASS_NAME,"_3704LK")
product.send_keys("Sneakers")
search = driver.find_element(By.CLASS_NAME,"_34RNph")
search.click()
count = 0
brand = []
desc = []
price =[]
off = []
Brand = driver.find_elements(By.XPATH,'//div[@class ="_2WkVRV"]')
Desc = driver.find_elements(By.XPATH,'//a[@class ="IRpwTa"]')
Price = driver.find_elements(By.XPATH,'//div[@class ="_30jeq3"]')
Off = driver.find_elements(By.XPATH,'//div[@class ="_3Ay6Sb"]//span')
if count <=100:
    for i in Brand:
        temp = i.text
        brand.append(temp)
    for i in Desc:
        temp = i.text
        desc.append(temp)
    for i in Price:
        temp = i.text
        price.append(temp)
    for i in Off:
        temp = i.text
        off.append(temp)
df = pd.DataFrame({'Brand':brand,'Description':desc,'Price':price,'OFF':off})
df

# %% [markdown]
# # Solution to Q7

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException
from selenium.webdriver.common.by import By
import time
driver = webdriver.Chrome(r"/Users/pallavishu/Downloads/chromedriver")
driver.get("https://www.myntra.com/shoes")
price_filter = driver.find_element(By.XPATH,'//input[@class="price-input" and @value = "6627.0 TO 13085.0"]')
price_filter.click()
color_filter = driver.find_element(By.XPATH,'//span[@class="colour-label colour-colorDisplay" and @style="background-color: rgb(54, 69, 79)"]')
color_filter.click()
brand = []
desc = []
price =[]
count = 0
Brand = driver.find_elements(By.XPATH,'//h3[@class="product-brand"]')
Desc = driver.find_elements(By.XPATH,'//h4[@class="product-product"]')
Price = driver.find_elements(By.XPATH,'//div[@class=product-price"]//span')
if count <=100:
    for i in Brand:
        BName = i.text
        brand.append(BName)
    for i in Desc:
        des = i.text
        desc.append(des)
    for i in Price:
        price = i.text
        price.append(price)
    count = count + 1
df = pd.DataFrame({'brand':brand,'product description':desc, 'price': price})
df

# %% [markdown]
# # Solution to Q8

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException
from selenium.webdriver.common.by import By
import time
driver = webdriver.Chrome(r"/Users/pallavishu/Downloads/chromedriver")
driver.get("https://www.amazon.in/")
product = driver.find_element(By.XPATH,'//input[@type="text" and @class="nav-input nav-progressive-attribute"]')
product.send_keys("Laptop")
search = driver.find_element(By.XPATH,'//input[@type="submit" and @class="nav-input nav-progressive-attribute"]')
search.click()
cpu = driver.find_element(By.XPATH,'//input[@id="p_n_feature_thirteen_browse-bin/12598163031"]//span')
cpu.click()
count =0
title = []
rating =[]
price =[]
Title =driver.find_elements(By.XPATH,'//h2[@class = "a-size-mini a-spacing-none a-color-base s-line-clamp-2"]')
Rating =driver.find_elements(By.XPATH,'//div[@class = "a-row a-size-small"]//span')
Price = driver.find_elements(By.XPATH,'//div[@class = "a-offscreen"]')
if count <= 10:
    for i in Title:
        temp = i.text
        title.append(temp)
    for i in Rating:
        temp = i.text
        rating.append(temp)
    for i in Price:
        temp = i.text
        price.append(temp)
    count = count + 1
df = pd.DataFrame({'Brand':brand,'Description':desc,'Price':price,'OFF':off})
df

# %% [markdown]
# # Solution to Q9

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException
from selenium.webdriver.common.by import By
import time
driver = webdriver.Chrome(r"/Users/pallavishu/Downloads/chromedriver")
driver.get("https://www.ambitionbox.com/")
job = driver.find_element(By.CLASS_NAME,"navItemLink")
job.click()
Input = driver.find_element(By.XPATH,'//input[@title ="Enter Designation, Company or a Skill"]')
Input.send_keys("Data Scientist")
search = driver.find_element(By.XPATH,'//button[@class = "ab_btn search-btn round"]')
search.click()
location_filter = driver.find_element(By.XPATH,'//div[@class="container filters-wrap job-filters noscrollbars-sm"]/div[2]')
location_filter.click()
noida = driver.find_element(By_XPATH,'//label[@class ="radio-label" and @data-v-5074abd8 for = "location_Noida"]')
noida.click()
title =[]
company =[]
exp = []
Title = driver.find_elements(By.XPATH,'//a[@class="title noclick"]')
Company = driver.find_elements(By.XPATH,'//p[@class="company body-medium"]')
Exp = driver.find_elements(By.XPATH,'//p[@class="body-small-l"]')
for i in Title[0:10]:
    temp = i.text
    title.append(temp)
for i in Company[0:10]:
    temp = i.text
    company.append(temp)
for i in Exp[0:10]:
    temp = i.text
    exp.append(temp)
df = pd.DataFrame({'Job tile':title,'Company name': company, 'Experiance': exp})
df

# %% [markdown]
# # Solution to Q10

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException
from selenium.webdriver.common.by import By
import time
driver = webdriver.Chrome(r"/Users/pallavishu/Downloads/chromedriver")
driver.get("https://www.ambitionbox.com/")
salary = driver.find_element(By.XPATH,'//ul[@class="nav-list-wrapper"]/li[3]')
salary.click()
sal = driver.find_element(By.XPATH,'//label[@class ="subNavListItem" and @href = "https://www.ambitionbox.com/salaries?campaign=desktop_nav"]')
sal.click()
Input = driver.find_element(By.XPATH,'//ul[@title="Enter a Company or Designation"]')
Input.send_keys("Data scientist")
search = driver.find_element(By.XPATH,'//button[@class = "ab_btn search-btn round component-search-btn"]/span')
search.click()
company = []
totalSalaries=[]
minSal=[]
maxSal=[]
avgSal=[]
exp =[]
Company =driver.find_element(By.XPATH,'//div[@class="name"]/a')
TotalSalaries =driver.find_element(By.XPATH,'//span[@class="salary-datapoints"]')
MinSal =driver.find_element(By.XPATH,'//div[@class="salary-values"]/div[0]')
MaxSal= driver.find_element(By.XPATH,'//div[@class="salary-values"]/div[0]')
AvgSal = driver.find_element(By.XPATH,'//p[@class="averageCtc"]/div[0]')
Exp = driver.find_element(By.XPATH,'//div[@class="sbold-list-header"]')
for i in Company[0:10]:
    temp = i.text
    company.append(temp)
for i in TotalSalaries[0:10]:
    temp = i.text
    totalSalaries.append(temp)
for i in MinSal[0:10]:
    temp = i.text
    minSal.append(temp)
for i in MaxSal[0:10]:
    temp = i.text
    maxSal.append(temp)
for i in AvgSal[0:10]:
    temp = i.text
    avgSal.append(temp)
for i in Exp[0:10]:
    temp = i.text
    exp.append(temp)
df= pd.DataFrame({'Company':company,'Toatal Salaries':totalSalaries,"Minimun Salary":minSal,"Maximum Salary":maxSal,"Average Salary":avgSal,"Experiance":exp})
