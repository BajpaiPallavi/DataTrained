# %%
import pandas as pd 
import numpy as np
import seaborn as sns
df = pd.read_csv("baseball.csv")
df.columns#printing all the columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# All column data are either int or float and gong further we dont need any encoding of data.

# %%
#Checking unique values in target column
df['W'].nunique()
# Out:
# 24

# %% [markdown]
# Since we have 24 unique values in target column hence it is a regression problem

# %%
#checking null values
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# No null values

# %%
#Checking space values in target column
df.loc[df['W']==" "]
# Out:
# Empty DataFrame
# Columns: [W, R, AB, H, 2B, 3B, HR, BB, SO, SB, RA, ER, ERA, CG, SHO, SV, E]
# Index: []

# %% [markdown]
# No space values

# %%
#plotting histogram to check win distribution
import matplotlib.pyplot as plt
# %matplotlib inline

# Plotting distribution of wins
plt.hist(df['W'])
plt.xlabel('Wins')
plt.title('Win distribution')

plt.show()

# %%
#Checking the distribution of all (as all are int or flot) columns
sns.distplot(df['W'],kde =True)
# Out:
# /Users/pallavishu/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='W', ylabel='Density'>

# %%
sns.distplot(df['R'],kde =True)
# Out:
# /Users/pallavishu/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='R', ylabel='Density'>

# %%
sns.distplot(df['AB'],kde =True)
# Out:
# /Users/pallavishu/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='AB', ylabel='Density'>

# %%
sns.distplot(df['H'],kde =True)
# Out:
# /Users/pallavishu/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='H', ylabel='Density'>

# %%
sns.distplot(df['2B'],kde =True)
# Out:
# /Users/pallavishu/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='2B', ylabel='Density'>

# %%
sns.distplot(df['3B'],kde =True)
# Out:
# /Users/pallavishu/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='3B', ylabel='Density'>

# %%
sns.distplot(df['HR'],kde =True)
# Out:
# /Users/pallavishu/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='HR', ylabel='Density'>

# %%
sns.distplot(df['BB'],kde =True)
# Out:
# /Users/pallavishu/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='BB', ylabel='Density'>

# %%
sns.distplot(df['SO'],kde =True)
# Out:
# /Users/pallavishu/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SO', ylabel='Density'>

# %%
sns.distplot(df['SB'],kde =True)
# Out:
# /Users/pallavishu/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SB', ylabel='Density'>

# %%
sns.distplot(df['RA'],kde =True)
# Out:
# /Users/pallavishu/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='RA', ylabel='Density'>

# %%
sns.distplot(df['ER'],kde =True)
# Out:
# /Users/pallavishu/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='ER', ylabel='Density'>

# %%
sns.distplot(df['ERA'],kde =True)
# Out:
# /Users/pallavishu/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='ERA', ylabel='Density'>

# %%
sns.distplot(df['CG'],kde =True)
# Out:
# /Users/pallavishu/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CG', ylabel='Density'>

# %%
sns.distplot(df['SHO'],kde =True)
# Out:
# /Users/pallavishu/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SHO', ylabel='Density'>

# %%
sns.distplot(df['SV'],kde =True)
# Out:
# /Users/pallavishu/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SV', ylabel='Density'>

# %%
sns.distplot(df['E'],kde =True)
# Out:
# /Users/pallavishu/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='E', ylabel='Density'>

# %%
#Printing the description
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize =(22,7))
sns.heatmap(df.describe(),annot =True,linewidths = 0.1, linecolor ="black", fmt = "0.2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# By comparing the mean and median value of each of the columns we find there is little skewness present in H,HR,CG,SHO,SV and E. Hence we need to remove it.

# %%
#Checking skewness
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
#Removing skewness using log method
df['H']= np.log(df['H'])
df['HR']= np.log(df['HR'])
df['CG']= np.log(df['CG'])
df['SHO']= np.log(df['SHO'])
df['SV']= np.log(df['SV'])
df['E']= np.log(df['E'])
# Out:
# /Users/pallavishu/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
#Checking coorelation of all columns with the target column
df.corr()['W'].sort_values()
# Out:
# ERA   -0.819600
# RA    -0.812952
# ER    -0.809435
# 3B    -0.251118
# SB    -0.157234
# E     -0.090235
# AB    -0.087947
# H      0.035305
# SO     0.111850
# CG     0.128128
# HR     0.319305
# 2B     0.427797
# SHO    0.429547
# R      0.430751
# BB     0.484342
# SV     0.667961
# W      1.000000
# Name: W, dtype: float64

# %%
#drawing correlation heatmap
plt.figure(figsize =(22,7))
sns.heatmap(df.corr(),annot =True,linewidths = 0.1, linecolor ="black", fmt = "0.2f")
# Out:
# <AxesSubplot:>

# %%
#Checking the correlation (+ve and -ve) with the target column in bar graph
plt.figure(figsize =(22,7))
df.corr()['W'].sort_values(ascending = False).drop(['W']).plot(kind= 'bar',color = "c")
plt.xlabel("features", fontsize = 14)
plt.ylabel("Column with target names", fontsize = 14)
plt.title("Correlation", fontsize =18)
plt.show()

# %%
#Plotting boxplot to check outliers
df_new =df[~df.isin([np.nan, np.inf, -np.inf]).any(1)]
# Out:
#       W    R    AB         H   2B  3B        HR   BB    SO   SB   RA   ER  \
# 0    95  724  5575  7.311218  300  42  4.934474  383   973  104  641  601
# 1    83  696  5467  7.207119  277  44  5.049856  439  1264   70  700  653
# 2    81  669  5439  7.240650  303  29  4.948760  533  1157   86  640  584
# 3    76  622  5533  7.230563  260  27  4.912655  404  1231   68  701  643
# 4    74  689  5605  7.323171  289  49  5.017280  455  1259   83  803  746
# 5    93  891  5509  7.299797  308  17  5.446737  570  1151   88  670  609
# 6    87  764  5567  7.242082  272  19  5.356586  554  1227   63  698  652
# 8    80  644  5485  7.232010  278  32  5.117994  436  1310   87  642  604
# 9    78  748  5640  7.309881  294  33  5.081404  478  1148   71  753  694
# 10   88  751  5511  7.257708  279  32  5.147494  503  1233  101  733  680
# 11   86  729  5459  7.217443  278  26  5.438079  486  1392  121  618  572
# 12   85  661  5417  7.193686  243  21  5.170484  435  1150   52  675  630
# ...

# %%
#checking outliers
df_new.plot(kind='box',subplots=True,layout=(3,6))
# Out:
# W         AxesSubplot(0.125,0.657941;0.110714x0.222059)
# R      AxesSubplot(0.257857,0.657941;0.110714x0.222059)
# AB     AxesSubplot(0.390714,0.657941;0.110714x0.222059)
# H      AxesSubplot(0.523571,0.657941;0.110714x0.222059)
# 2B     AxesSubplot(0.656429,0.657941;0.110714x0.222059)
# 3B     AxesSubplot(0.789286,0.657941;0.110714x0.222059)
# HR        AxesSubplot(0.125,0.391471;0.110714x0.222059)
# BB     AxesSubplot(0.257857,0.391471;0.110714x0.222059)
# SO     AxesSubplot(0.390714,0.391471;0.110714x0.222059)
# SB     AxesSubplot(0.523571,0.391471;0.110714x0.222059)
# RA     AxesSubplot(0.656429,0.391471;0.110714x0.222059)
# ER     AxesSubplot(0.789286,0.391471;0.110714x0.222059)
# ERA          AxesSubplot(0.125,0.125;0.110714x0.222059)
# CG        AxesSubplot(0.257857,0.125;0.110714x0.222059)
# SHO       AxesSubplot(0.390714,0.125;0.110714x0.222059)
# SV        AxesSubplot(0.523571,0.125;0.110714x0.222059)
# E         AxesSubplot(0.656429,0.125;0.110714x0.222059)
# ...

# %% [markdown]
# Outliers are present in column SHO,E,R and SB hence we will remove them.

# %%
#removing outliers using Zscore
from scipy.stats import zscore

z= np.abs(zscore(df_new))
np.where(z>3)
# Out:
# (array([5]), array([1]))

# %%
df_new_z = df_new[(z<3).all(axis=1)]
df_new_z.shape
# Out:
# (26, 17)

# %%
data_loss = ((30-27)/30)*100
data_loss
# Out:
# 10.0

# %%
#Dividing data into x and y i.e input and target
x=df_new_z.iloc[:,1:]# independent variables
y=df_new_z.iloc[:,1]#target

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %% [markdown]
# # Applying models to check accuracy score

# %%
from sklearn.svm import SVR
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
# SVR
Kernel =['linear','poly','rbf']
for i in Kernel:
    sv =SVR(kernel='linear')
    sv.fit(X_train,y_train)
    predsv= sv.predict(X_test)
    print("#####Accuracy score with", i, "is:#####\n",sv.score(X_train,y_train))
# Out:
# #####Accuracy score with linear is:#####
#  0.9999969012224608
# #####Accuracy score with poly is:#####
#  0.9999969012224608
# #####Accuracy score with rbf is:#####
#  0.9999969012224608

# %% [markdown]
# Score is same in all kernels

# %%
# K neighbour
from sklearn.neighbors import KNeighborsRegressor
kn = KNeighborsRegressor()
kn.fit(X_train,y_train)
predkn= kn.predict(X_test)
print("#####Accuracy score is:#####\n",kn.score(X_train,y_train))
# Out:
# #####Accuracy score is:#####
#  0.5826562748219309

# %%
#Logistic regression
from sklearn.linear_model import LogisticRegression
lr= LogisticRegression()
lr.fit(X_train,y_train)
predlr=lr.predict(X_test)
print("#####Accuracy score with is:#####\n",lr.score(X_train,y_train))
# Out:
# #####Accuracy score with is:#####
#  1.0
# /Users/pallavishu/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#Decision tree regressor
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor()
dtr.fit(X_train,y_train)
preddtr=dtr.predict(X_test)
print("#####Accuracy score with is:#####\n",dtr.score(X_train,y_train))
# Out:
# #####Accuracy score with is:#####
#  1.0

# %%
#MultinomialNB
from sklearn.naive_bayes import MultinomialNB
mn =MultinomialNB()
mn.fit(X_train,y_train)
predmn=mn.predict(X_test)
print("#####Accuracy score with is:#####\n",mn.score(X_train,y_train))
# Out:
# #####Accuracy score with is:#####
#  0.9411764705882353

# %% [markdown]
# DTR and LR gives the accuracy score of 1 hence saving the DTR model

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr = GradientBoostingRegressor()
gbr.fit(X_train, y_train)
predmn=gbr.predict(X_test)
print("#####Accuracy score with is:#####\n",gbr.score(X_train,y_train))
# Out:
# #####Accuracy score with is:#####
#  0.9999999989410564

# %% [markdown]
# # Saving model

# %%
#Saving and loading the model
import pickle
file_name = "churn.pkl"
pickle.dump(dtr,open(file_name,"wb"))
#loading model
loaded_model = pickle.load(open("churn.pkl","rb"))
result = loaded_model.score(X_test,y_test)
conclusion =pd.DataFrame([loaded_model.predict(X_test)[:],preddtr[:]],index = ["Predicted","Original"])
conclusion
# Out:
#                0      1      2      3      4      5      6      7      8
# Predicted  748.0  667.0  764.0  644.0  667.0  764.0  626.0  696.0  696.0
# Original   748.0  667.0  764.0  644.0  667.0  764.0  626.0  696.0  696.0
