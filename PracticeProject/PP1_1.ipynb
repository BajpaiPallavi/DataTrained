# %%
import pandas as pd 
import numpy as np
import seaborn as sns
df = pd.read_csv("happiness_score_dataset.csv")
df.columns#printing all the columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.dtypes #Printing the datatypes of all columns
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# we have 2 columns of type object, 1 column of type int and 9 columns of type float

# %%
df['Happiness Score'].nunique()
# Out:
# 157

# %% [markdown]
# Since we have 157 unique values in target column hence it is a regression problem

# %%
df.loc[df['Happiness Score']==" "]#Checking if target column have space as values
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Standard Error, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %% [markdown]
# Dataset is not having any space value

# %%
df.isnull().sum()# Checking if coluumns have null values
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# Dataset is not having any null value

# %%
#Making dataframe nominal
df_visualization_nominal = df[['Country', 'Region', 'Happiness Rank', 'Happiness Score', 'Standard Error', 'Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom','Trust (Government Corruption)','Generosity','Dystopia Residual']].copy()

# %%
#
#Visualization of data
from matplotlib import pyplot as plt
plt.figure(figsize=(18,8))
ax = sns.countplot(x="Country",data=df_visualization_nominal)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
print(df_visualization_nominal["Country"].value_counts())
# Out:
# Armenia         1
# Malaysia        1
# Laos            1
# Slovakia        1
# Germany         1
#                ..
# Zambia          1
# Saudi Arabia    1
# Belarus         1
# Venezuela       1
# Rwanda          1
# Name: Country, Length: 158, dtype: int64

# %%
#
plt.figure(figsize=(16,8))
ax = sns.countplot(x="Region",data=df_visualization_nominal)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
print(df_visualization_nominal["Region"].value_counts())
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %%
#
plt.figure(figsize=(16,8))
ax = sns.countplot(x="Happiness Rank",data=df_visualization_nominal)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
print(df_visualization_nominal["Happiness Rank"].value_counts())
# Out:
# 82     2
# 1      1
# 110    1
# 103    1
# 104    1
#       ..
# 54     1
# 55     1
# 56     1
# 57     1
# 158    1
# Name: Happiness Rank, Length: 157, dtype: int64

# %%
#
plt.figure(figsize=(16,8))
ax = sns.countplot(x="Happiness Score",data=df_visualization_nominal)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
print(df_visualization_nominal["Happiness Score"].value_counts())
# Out:
# 5.192    2
# 5.548    1
# 4.867    1
# 4.800    1
# 3.896    1
#         ..
# 5.759    1
# 4.677    1
# 6.901    1
# 6.003    1
# 6.611    1
# Name: Happiness Score, Length: 157, dtype: int64

# %%
#
plt.figure(figsize=(16,8))
ax = sns.countplot(x="Standard Error",data=df_visualization_nominal)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
print(df_visualization_nominal["Standard Error"].value_counts())
# Out:
# 0.05051    2
# 0.04394    2
# 0.03780    2
# 0.04934    2
# 0.03751    2
#           ..
# 0.04742    1
# 0.02799    1
# 0.04615    1
# 0.03260    1
# 0.05800    1
# Name: Standard Error, Length: 153, dtype: int64

# %%
#
plt.figure(figsize=(16,8))
ax = sns.countplot(x="Economy (GDP per Capita)",data=df_visualization_nominal)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40)
print(df_visualization_nominal["Economy (GDP per Capita)"].value_counts())
# Out:
# 0.00000    1
# 0.66320    1
# 0.92053    1
# 0.33024    1
# 1.69042    1
#           ..
# 0.23906    1
# 0.93929    1
# 0.91851    1
# 0.37545    1
# 0.79907    1
# Name: Economy (GDP per Capita), Length: 158, dtype: int64

# %%
#
plt.figure(figsize=(16,8))
ax = sns.countplot(x="Family",data=df_visualization_nominal)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
print(df_visualization_nominal["Family"].value_counts())
# Out:
# 0.88767    1
# 1.25712    1
# 0.94675    1
# 1.15115    1
# 0.91612    1
#           ..
# 0.77115    1
# 1.36948    1
# 0.47489    1
# 0.60406    1
# 0.91916    1
# Name: Family, Length: 158, dtype: int64

# %%
#
plt.figure(figsize=(16,8))
ax = sns.countplot(x="Health (Life Expectancy)",data=df_visualization_nominal)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
print(df_visualization_nominal["Health (Life Expectancy)"].value_counts())
# Out:
# 0.92356    2
# 0.07612    1
# 0.88911    1
# 0.89042    1
# 0.22562    1
#           ..
# 0.83947    1
# 0.73017    1
# 0.75905    1
# 0.78723    1
# 0.56874    1
# Name: Health (Life Expectancy), Length: 157, dtype: int64

# %%
#
ax = sns.countplot(x="Freedom",data=df_visualization_nominal)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
print(df_visualization_nominal["Freedom"].value_counts())
# Out:
# 0.00000    1
# 0.23414    1
# 0.49049    1
# 0.22815    1
# 0.49309    1
#           ..
# 0.40840    1
# 0.60362    1
# 0.40672    1
# 0.10081    1
# 0.60855    1
# Name: Freedom, Length: 158, dtype: int64

# %%
#
ax = sns.countplot(x="Trust (Government Corruption)",data=df_visualization_nominal)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
print(df_visualization_nominal["Trust (Government Corruption)"].value_counts())
# Out:
# 0.32524    2
# 0.00000    1
# 0.12474    1
# 0.08546    1
# 0.28703    1
#           ..
# 0.10731    1
# 0.06358    1
# 0.37124    1
# 0.39928    1
# 0.05863    1
# Name: Trust (Government Corruption), Length: 157, dtype: int64

# %%
#
ax = sns.countplot(x="Generosity",data=df_visualization_nominal)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
print(df_visualization_nominal["Generosity"].value_counts())
# Out:
# 0.00000    1
# 0.32296    1
# 0.37744    1
# 0.12332    1
# 0.40828    1
#           ..
# 0.33088    1
# 0.32573    1
# 0.28310    1
# 0.16388    1
# 0.16979    1
# Name: Generosity, Length: 158, dtype: int64

# %%
#
ax = sns.countplot(x="Dystopia Residual",data=df_visualization_nominal)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
print(df_visualization_nominal["Dystopia Residual"].value_counts())
# Out:
# 2.72230    1
# 2.12466    1
# 1.88931    1
# 2.53942    1
# 1.96994    1
#           ..
# 2.06367    1
# 2.46531    1
# 1.73933    1
# 2.26425    1
# 2.11399    1
# Name: Dystopia Residual, Length: 158, dtype: int64

# %%
#Checking the distribution of float and int type columns
df_visualization_continous =df[["Happiness Rank","Happiness Score","Standard Error","Economy (GDP per Capita)","Family","Health (Life Expectancy)","Freedom","Trust (Government Corruption)","Generosity","Dystopia Residual"]].copy()

# %%
sns.distplot(df_visualization_continous['Happiness Rank'],kde =True)
# Out:
# /Users/pallavishu/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Happiness Rank', ylabel='Density'>

# %%
sns.distplot(df_visualization_continous['Happiness Score'],kde =True)
# Out:
# /Users/pallavishu/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Happiness Score', ylabel='Density'>

# %%
sns.distplot(df_visualization_continous['Standard Error'],kde =True)
# Out:
# /Users/pallavishu/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Standard Error', ylabel='Density'>

# %%
sns.distplot(df_visualization_continous['Economy (GDP per Capita)'],kde =True)
# Out:
# /Users/pallavishu/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Density'>

# %%
sns.distplot(df_visualization_continous['Family'],kde =True)
# Out:
# /Users/pallavishu/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Family', ylabel='Density'>

# %%
sns.distplot(df_visualization_continous['Health (Life Expectancy)'],kde =True)
# Out:
# /Users/pallavishu/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Density'>

# %%
sns.distplot(df_visualization_continous['Freedom'],kde =True)
# Out:
# /Users/pallavishu/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Freedom', ylabel='Density'>

# %%
sns.distplot(df_visualization_continous['Trust (Government Corruption)'],kde =True)
# Out:
# /Users/pallavishu/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %%
sns.distplot(df_visualization_continous['Generosity'],kde =True)
# Out:
# /Users/pallavishu/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Generosity', ylabel='Density'>

# %%
sns.distplot(df_visualization_continous['Dystopia Residual'],kde =True)
# Out:
# /Users/pallavishu/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Density'>

# %%
#Since we have data of rest of columns as object we will use encoding techniques to convert it into numeric data
from sklearn.preprocessing import OrdinalEncoder

enc = OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes == "object":
        df[i] = enc.fit_transform(df[i].values.reshape(-1,1))
df.describe()
# Out:
#           Country      Region  Happiness Rank  Happiness Score  \
# count  158.000000  158.000000      158.000000       158.000000
# mean    78.500000    5.120253       79.493671         5.375734
# std     45.754781    2.993321       45.754363         1.145010
# min      0.000000    0.000000        1.000000         2.839000
# 25%     39.250000    3.000000       40.250000         4.526000
# 50%     78.500000    4.500000       79.500000         5.232500
# 75%    117.750000    8.000000      118.750000         6.243750
# max    157.000000    9.000000      158.000000         7.587000
#
#        Standard Error  Economy (GDP per Capita)      Family  \
# count      158.000000                158.000000  158.000000
# mean         0.047885                  0.846137    0.991046
# std          0.017146                  0.403121    0.272369
# min          0.018480                  0.000000    0.000000
# 25%          0.037268                  0.545808    0.856823
# ...

# %% [markdown]
# By comparing the mean and median value of each of int and flot columns we fing there is no skewness present

# %%
import matplotlib.pyplot as plt
plt.figure(figsize =(22,7))
sns.heatmap(df.describe(),annot =True,linewidths = 0.1, linecolor ="black", fmt = "0.2f")
# Out:
# <AxesSubplot:>

# %%
#Checking coorelation of all columns with the target column
df.corr()['Happiness Score'].sort_values()
# Out:
# Happiness Rank                  -0.992105
# Standard Error                  -0.177254
# Region                          -0.176791
# Country                          0.083380
# Generosity                       0.180319
# Trust (Government Corruption)    0.395199
# Dystopia Residual                0.530474
# Freedom                          0.568211
# Health (Life Expectancy)         0.724200
# Family                           0.740605
# Economy (GDP per Capita)         0.780966
# Happiness Score                  1.000000
# Name: Happiness Score, dtype: float64

# %%
#drawing correlation heatmap
plt.figure(figsize =(22,7))
sns.heatmap(df.corr(),annot =True,linewidths = 0.1, linecolor ="black", fmt = "0.2f")
# Out:
# <AxesSubplot:>

# %%
#Checking the correlation (+ve and -ve) with the target column in bar graph
plt.figure(figsize =(22,7))
df.corr()['Happiness Score'].sort_values(ascending = False).drop(['Happiness Score']).plot(kind= 'bar',color = "c")
plt.xlabel("features", fontsize = 14)
plt.ylabel("Column with target names", fontsize = 14)
plt.title("Correlation", fontsize =18)
plt.show()

# %%
#Checking skewness
df.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
#Checking outliers for int and flot type columns (initially)
df["Happiness Rank"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["Happiness Score"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["Standard Error"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["Economy (GDP per Capita)"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["Family"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["Health (Life Expectancy)"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["Freedom"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["Trust (Government Corruption)"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["Generosity"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["Dystopia Residual"].plot.box()
# Out:
# <AxesSubplot:>

# %%
#Checking oulier data
from scipy.stats import zscore
import numpy as np
z= np.abs(zscore(df))
threshhold = 3
np.where(z>3)
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157]),
#  array([ 9,  4,  4,  4, 10,  6,  9, 11,  6]))

# %%
#Removing outliers and finding data loss
df_new_z = df[(z<3).all(axis=1)]
data_loss = ((7043-6361)/7043)*100
data_loss
# Out:
# 9.683373562402386

# %%
#Seperating input and output as features and target
features = df.drop("Happiness Score",axis =1)
target = df["Happiness Score"]

# %%
#Scaling the data using min max scaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import warnings
mms = MinMaxScaler()
lr = LinearRegression()
warnings.filterwarnings("ignore")
for i in range(0,100):
    features_train, features_test, target_train, target_test = train_test_split(features,target,test_size = 0.2,random_state =i)
    lr.fit(features_train,target_train)
    pred_train = lr.predict(features_train)
    pred_test = lr.predict(features_test)
    print(f"at random state {i}, the train accuracy is: {r2_score(target_train,pred_train)}")
    print(f"at random state {i}, the test accuracy is: {r2_score(target_test,pred_test)}")
    print("\n")
# Out:
# at random state 0, the train accuracy is: 0.9999999514441257
# at random state 0, the test accuracy is: 0.999999902494247
#
#
# at random state 1, the train accuracy is: 0.9999999444138908
# at random state 1, the test accuracy is: 0.9999999394454414
#
#
# at random state 2, the train accuracy is: 0.9999999405491521
# at random state 2, the test accuracy is: 0.9999999523828854
#
#
# at random state 3, the train accuracy is: 0.9999999420745156
# at random state 3, the test accuracy is: 0.9999999470792729
#
#
# at random state 4, the train accuracy is: 0.9999999379277369
# at random state 4, the test accuracy is: 0.9999999520348243
#
#
# at random state 5, the train accuracy is: 0.9999999487684214
# at random state 5, the test accuracy is: 0.9999999027545904
#
#
# at random state 6, the train accuracy is: 0.9999999463039511
# at random state 6, the test accuracy is: 0.9999999338566166
#
#
# at random state 7, the train accuracy is: 0.9999999443622295
# ...

# %%
#we are selecting random state as 80 because at i=72 we are getting highest test accuracy
features_train, features_test, target_train, target_test = train_test_split(features,target,test_size = 0.2,random_state =72)
#training the model
lr.fit(features_train,target_train)
#Predicting values
pred_test = lr.predict(features_test)
print(r2_score(target_test,pred_test))
# Out:
# 0.9999999687861033

# %%
#Cross validation of model
Training_accuracy = r2_score(target_train,pred_train)
Test_accuracy = r2_score(target_test,pred_test)
from sklearn.model_selection import cross_val_score
#Checking at what random state we have highest cross validation score and test accuracy
for j in range(2,10):
    cv_score = cross_val_score(lr,features,target,cv=j)#cv = j means my data will be divided into j equal parts
    cv_mean= cv_score.mean()
    print(f"At cross fold {j} the cv score is: {cv_mean} and accuracy score for training is: {Training_accuracy} and accuracy for testing is: {Test_accuracy}")
    print("\n")
# Out:
# At cross fold 2 the cv score is: 0.9999997284501867 and accuracy score for training is: -0.9608369241182011 and accuracy for testing is: 0.9999999687861033
#
#
# At cross fold 3 the cv score is: 0.9999994758122854 and accuracy score for training is: -0.9608369241182011 and accuracy for testing is: 0.9999999687861033
#
#
# At cross fold 4 the cv score is: 0.9999988371717737 and accuracy score for training is: -0.9608369241182011 and accuracy for testing is: 0.9999999687861033
#
#
# At cross fold 5 the cv score is: 0.9999982417917263 and accuracy score for training is: -0.9608369241182011 and accuracy for testing is: 0.9999999687861033
#
#
# At cross fold 6 the cv score is: 0.9999971509064253 and accuracy score for training is: -0.9608369241182011 and accuracy for testing is: 0.9999999687861033
#
#
# At cross fold 7 the cv score is: 0.99999580182807 and accuracy score for training is: -0.9608369241182011 and accuracy for testing is: 0.9999999687861033
#
#
# ...

# %% [markdown]
# Since the no. of folds do not have any impact on test accuracy and cv score so we are selecting j =5
#
# here we have handeled the problem of overfitting and underfitting by checking the training and testing score

# %%
cv_score = cross_val_score(lr,features,target,cv=5)#cv = j means my data will be divided into j equal parts
cv_mean= cv_score.mean()

# %%
#drawing scatterplot to confirm the best fit line
import matplotlib.pyplot as plt
plt.figure(figsize = (8,6))
plt.scatter(x= target_test,y=pred_test,color = "r")
plt.plot(target_test,target_test, color = "b")
plt.xlabel("Actual Charges",fontsize = 14)
plt.ylabel("Predicted Charges", fontsize = 14)
plt.title("Linear Regression", fontsize = 18)
plt.savefig("lr.png")
plt.show()

# %% [markdown]
# best fit line is covering most of the datapoints which shows good fit of our model

# %%
#regularization to remove overfitting and underfitting
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings("ignore")
from sklearn.linear_model import Lasso
parameters = {'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,10))}
ls =Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(features_train,target_train)
print(clf.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 0}

# %%
#training as per best params
ls =Lasso(alpha =0.0001, random_state = 0)
ls.fit(features_train,target_train)
ls_score_training=ls.score(features_train,target_train)
pred_ls = ls.predict(features_test)
ls_score_training*100
# Out:
# 99.99736908041214

# %%
#getting ls score
lss = r2_score(target_test,pred_ls)
lss*100
# Out:
# 99.99746197903579

# %%
#getting cv score
cv_score = cross_val_score(ls,features,target,cv=5)
cv_mean = cv_score.mean()
cv_mean*100
# Out:
# 99.87116482551457

# %%
#Ensembling
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
import warnings
warnings.filterwarnings("ignore")
from sklearn.linear_model import Lasso
parameters = {'criterion':['mse','mse'],'max_features':["auto","sqrt","log2"]}
rf =RandomForestRegressor()
clf = GridSearchCV(rf,parameters)
clf.fit(features_train,target_train)
print(clf.best_params_)
#training as per best params
rf =RandomForestRegressor(criterion ="mae", max_features = "auto")
rf.fit(features_train,target_train)
rf.score(features_train,target_train)
pred_decision = rf.predict(features_test)
#getting ls score
rfs= r2_score(target_test,pred_ls)
rfs*100
#getting cv score
rf_score = cross_val_score(rf,features,target,cv=5)
rf_mean = cv_score.mean()
rf_mean*100
# Out:
# {'criterion': 'mse', 'max_features': 'auto'}
# 99.87116482551457

# %%
#Saving and loading the model
import pickle
file_name = "churn.pkl"
pickle.dump(rf,open(file_name,"wb"))
#loading model
loaded_model = pickle.load(open("churn.pkl","rb"))
result = loaded_model.score(features_test,target_test)
print(result*100)
conclusion =pd.DataFrame([loaded_model.predict(features_test)[:],pred_decision[:]],index = ["Predicted","Original"])
conclusion
# Out:
# 99.3895220391535
#                 0        1       2        3        4        5        6   \
# Predicted  6.48945  6.56814  6.8173  3.46303  7.18686  6.81407  3.72513
# Original   6.48945  6.56814  6.8173  3.46303  7.18686  6.81407  3.72513
#
#                 7        8        9   ...       22       23       24       25  \
# Predicted  5.74319  6.97132  3.24924  ...  3.55416  3.93606  5.40855  6.35285
# Original   5.74319  6.97132  3.24924  ...  3.55416  3.93606  5.40855  6.35285
#
#                 26       27       28       29       30      31
# Predicted  6.66164  5.08808  3.55154  7.33806  7.28552  3.8548
# Original   6.66164  5.08808  3.55154  7.33806  7.28552  3.8548
#
# [2 rows x 32 columns]
